# %%
# Import Required Libraries
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import numpy as np

# Load and Display Original Image
image_path = 'data/rps/paper/paper01-000.png'
original_image = Image.open(image_path)
original_image_cv = cv2.cvtColor(np.array(original_image), cv2.COLOR_RGB2BGR)

plt.figure(figsize=(10, 5))

# Display Original Image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(original_image)

# Define Transformations
def normalize_image(image):
    image = cv2.resize(image, (300, 300))
    image = image / 255.0  # Scale to [0, 1]
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    normalized_image = (image - mean) / std
    return normalized_image

# Apply Transformations
transformed_image_cv = normalize_image(original_image_cv)

# Display Normalized Image
plt.subplot(1, 2, 2)
plt.title('Normalized Image')
plt.imshow(transformed_image_cv)

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8096583611610584..2.6399999999999997].
